# %%
import pandas as pd

# %%
df=pd.read_csv("Base_File.csv")
df
# Out:
#            city  order_date         source                  order_id  \
# 0     BENGALURU  02-12-2022            APP  638a041b12c34481a4ca9b0b
# 1     BENGALURU  04-12-2022            APP  638c362a12c344432fcad7e0
# 2     BENGALURU  09-12-2022    Inbound-SEM  6392b02f8e918ba040eff59f
# 3         DELHI  12-12-2022  Outbound Lead  6396f7fd49867aa6f2e2f576
# 4         DELHI  17-12-2022    Inbound-SEM  639d986c49867af659e3de82
# ...         ...         ...            ...                       ...
# 9679      Delhi  22-01-2023    Exotel Lead  63cd10725cb8ef3e0ebb4c4b
# 9680    Chennai  22-01-2023  Phlebo Upsell  63cd1b8c5cb8efbf99bb4deb
# 9681  Bengaluru  22-01-2023            APP  63cd1ddd95fc10e54f976d9e
# 9682      Other  22-01-2023        Support  63cd20515cb8ef26f9bb4eac
# 9683     Mumbai  22-01-2023  Phlebo Upsell  63cd265195fc10459c976f66
#
#       booking_amount actual_city_name seller_locality         payment_mode  \
# ...

# %%
df.tail()
# Out:
#            city  order_date         source                  order_id  \
# 9679      Delhi  22-01-2023    Exotel Lead  63cd10725cb8ef3e0ebb4c4b
# 9680    Chennai  22-01-2023  Phlebo Upsell  63cd1b8c5cb8efbf99bb4deb
# 9681  Bengaluru  22-01-2023            APP  63cd1ddd95fc10e54f976d9e
# 9682      Other  22-01-2023        Support  63cd20515cb8ef26f9bb4eac
# 9683     Mumbai  22-01-2023  Phlebo Upsell  63cd265195fc10459c976f66
#
#       booking_amount actual_city_name seller_locality payment_mode  \
# 9679          825.30        New Delhi           DELHI          POD
# 9680          300.30          Chennai         CHENNAI          POD
# 9681          996.52        Bengaluru       BENGALURU          POD
# 9682         1820.70          Sasaram             NaN          POD
# 9683          375.30           Mumbai      THANE WEST          POD
#
#      logistic_provider_name fulfillment_type package_type sample_type
# 9679           Lifecell Now          AT-HOME     Lab-Test       other
# ...

# %%
df.describe()
# Out:
#        booking_amount
# count     9668.000000
# mean      1572.179946
# std       1819.224066
# min          0.000000
# 25%        550.000000
# 50%       1000.000000
# 75%       1950.000000
# max      22227.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9684 entries, 0 to 9683
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    9680 non-null   object
#  1   order_date              9683 non-null   object
#  2   source                  9683 non-null   object
#  3   order_id                9684 non-null   object
#  4   booking_amount          9668 non-null   float64
#  5   actual_city_name        9679 non-null   object
#  6   seller_locality         8405 non-null   object
#  7   payment_mode            9683 non-null   object
#  8   logistic_provider_name  4085 non-null   object
#  9   fulfillment_type        9684 non-null   object
#  10  package_type            9684 non-null   object
#  11  sample_type             9684 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 908.0+ KB

# %%
df.isnull().sum()
# Out:
# city                         4
# order_date                   1
# source                       1
# order_id                     0
# booking_amount              16
# actual_city_name             5
# seller_locality           1279
# payment_mode                 1
# logistic_provider_name    5599
# fulfillment_type             0
# package_type                 0
# sample_type                  0
# dtype: int64

# %%
df.dropna(how='any').shape
# Out:
# (2811, 12)

# %%
temp = df.dropna(how='any')

# %%
temp
# Out:
#            city  order_date         source                  order_id  \
# 20        Delhi  28-12-2022    Inbound-SEM  63ac17598e918bfbfef3579c
# 22    Hyderabad  28-12-2022      IB-UPSELL  63ac2e4949867a286be5d3ab
# 28    Bengaluru  29-12-2022    Opportunity  63ad489a8e918b2f15f38062
# 29    Bengaluru  29-12-2022   Agent Upsell  63ad48f949867a4d1ee5f627
# 36    Bengaluru  29-12-2022            APP  63adaafc49867a9ff9e60c4c
# ...         ...         ...            ...                       ...
# 9675  Hyderabad  22-01-2023    Inbound-SEM  63ccf81995fc102d06976831
# 9679      Delhi  22-01-2023    Exotel Lead  63cd10725cb8ef3e0ebb4c4b
# 9680    Chennai  22-01-2023  Phlebo Upsell  63cd1b8c5cb8efbf99bb4deb
# 9681  Bengaluru  22-01-2023            APP  63cd1ddd95fc10e54f976d9e
# 9683     Mumbai  22-01-2023  Phlebo Upsell  63cd265195fc10459c976f66
#
#       booking_amount actual_city_name seller_locality payment_mode  \
# 20              0.00        Ghaziabad         GURGOAN          POD
# ...

# %%
temp=df['Radiography'] = df['package_type']+df['sample_type']

# %%
temp
# Out:
# 0               HAother
# 1               HAother
# 2       Lab-Testimaging
# 3       Lab-Testimaging
# 4       Lab-Testimaging
#              ...
# 9679      Lab-Testother
# 9680      Lab-Testother
# 9681      Lab-Testother
# 9682      Lab-Testother
# 9683      Lab-Testother
# Length: 9684, dtype: object

# %%
total_bokking_amount = df['booking_amount'].sum().round()
total_bokking_amount
# Out:
# 15199836.0

# %%
order_count=df['order_id'].count()
order_count
# Out:
# 9684

# %%
df['payment_mode'].count()
# Out:
# 9683

# %%
df.to_csv('clean_data.csv')
